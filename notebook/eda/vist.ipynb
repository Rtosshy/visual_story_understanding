# %%
import sys
from pathlib import Path

# ノートブックのカレントディレクトリを確認して、project root を推定する
print("cwd:", Path.cwd())
proj_root = Path.cwd().parents[1]  # notebook/eda -> ../.. がリポジトリルート
print("project root guessed:", proj_root)

# 先頭に挿入して import の優先検索先にする
sys.path.insert(0, str(proj_root))

# 動作確認
import importlib

try:
    import src.paths as _p

    importlib.reload(_p)
    print("src is importable:", _p)
except Exception as e:
    print("import failed:", e)
# Out:
# cwd: /Users/toshiyukimannen/ghq/github.com/Rtosshy/visual_story_understanding/notebook/eda
# project root guessed: /Users/toshiyukimannen/ghq/github.com/Rtosshy/visual_story_understanding
# src is importable: <module 'src.paths' from '/Users/toshiyukimannen/ghq/github.com/Rtosshy/visual_story_understanding/src/paths.py'>

# %%
import json
import random
import re

import pandas as pd
from num2words import num2words
from src.paths import VIST_IMAGE_ROOT, VIST_JSON_ROOT

# %%
dii_test_json_path = VIST_JSON_ROOT / "dii" / "test.description-in-isolation.json"
sis_test_json_path = VIST_JSON_ROOT / "sis" / "test.story-in-sequence.json"
test_image_path = VIST_IMAGE_ROOT / "test"

# %%
def load_json(path):
    with path.open("r", encoding="utf-8") as f:
        return json.load(f)

# %%
dii_test = load_json(dii_test_json_path)
sis_test = load_json(sis_test_json_path)

# %%
print(dii_test.keys())
print(sis_test.keys())
# Out:
# dict_keys(['images', 'info', 'albums', 'type', 'annotations'])
# dict_keys(['images', 'info', 'albums', 'type', 'annotations'])

# %%
def convert_numbers_to_words(text: str) -> str:
    # 連続する数字をまとめて変換
    return re.sub(r"\d+", lambda m: num2words(int(m.group()), lang="en"), text)

# %%
dii_test_annotations_df = pd.DataFrame(dii_test["annotations"])
dii_test_annotations_df = dii_test_annotations_df[0].apply(pd.Series)
dii_test_annotations_df.head(10)
# Out:
#                                        original_text album_id photo_flickr_id  \
# 0  The sign is describing when the services will ...    44277         1741642
# 1  Sitting there waiting on someone to come over ...    44277         1741640
# 2  a case full of books in a house, books appear ...    44277         1741632
# 3  A older man with a black hat, mustache and gla...    44277         1741622
# 4  A man in a top hat has a magic trick on the fl...    44277         1741587
# 5  outer brick wall with red sign indicating name...    44277         1741642
# 6  A red table with many cards and memorabilia di...    44277         1741640
# 7                 A box on the ground full of books,    44277         1741632
# 8   man talking to someone wearing glasses and a hat    44277         1741622
# 9  The man is kneeling down looking at some objec...    44277         1741587
#
#    photo_order_in_story        worker_id  \
# 0                     0  X8GRFNA3PAZ87NZ
# 1                     1  PB3OFZ78X1DCMNG
# 2                     2  HLW494OD75LWCLB
# 3                     3  W8PVUI94S55I9MR
# 4                     4  NHSTZ8KYF85P97G
# 5                     0  Z8EVTCFDLQ7XIN7
# 6                     1  X9VMA8VJB1W1P2O
# 7                     2  FBK532ILCABYOS0
# 8                     3  3EDPCPIXOFVNSHK
# 9                     4  L3OOAQVTECPJXM0
#
#                                                 text  \
# 0  the sign is describing when the services will ...
# 1  sitting there waiting on someone to come over ...
# 2  a case full of books in a house , books appear...
# 3  a older man with a black hat , mustache and gl...
# 4  a man in a top hat has a magic trick on the fl...
# 5  outer brick wall with red sign indicating name...
# 6  a red table with many cards and memorabilia di...
# 7                a box on the ground full of books ,
# 8   man talking to someone wearing glasses and a hat
# 9  the man is kneeling down looking at some objec...
#
#                         tier
# 0  descriptions-in-isolation
# 1  descriptions-in-isolation
# 2  descriptions-in-isolation
# 3  descriptions-in-isolation
# 4  descriptions-in-isolation
# 5  descriptions-in-isolation
# 6  descriptions-in-isolation
# 7  descriptions-in-isolation
# 8  descriptions-in-isolation
# 9  descriptions-in-isolation

# %%
sis_test_annotations_df = pd.DataFrame(sis_test["annotations"])
sis_test_annotations_df = sis_test_annotations_df[0].apply(pd.Series)
sis_test_annotations_df.head(10)
# Out:
#                                        original_text album_id photo_flickr_id  \
# 0     The local parish holds a craft show each year.    44277         1741642
# 1  Lots of folks come out and set up tables to se...    44277         1741640
# 2  Some of these crafts are very unique and take ...    44277         1741632
# 3  Folks of all ages come out to peruse the craft...    44277         1741622
# 4  Some of the crafters even dress up in unique c...    44277         1741587
# 5  I was so excited to be heading to the crafts f...    44277         1741625
# 6  When I arrived I saw a great booth with a vari...    44277         1741640
# 7  I stopped at chatted at my friend Beth's booth...    44277         1741639
# 8  There were even booths set up for all of the k...    44277         1741633
# 9  I found some awesome crafts at the fair, I'm r...    44277         1741630
#
#                  setting        worker_id story_id               tier  \
# 0  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
# 1  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
# 2  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
# 3  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
# 4  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
# 5  first-2-pick-and-tell  Y6ZNXABP31FUVQ8    45531  story-in-sequence
# 6  first-2-pick-and-tell  Y6ZNXABP31FUVQ8    45531  story-in-sequence
# 7  first-2-pick-and-tell  Y6ZNXABP31FUVQ8    45531  story-in-sequence
# 8  first-2-pick-and-tell  Y6ZNXABP31FUVQ8    45531  story-in-sequence
# 9  first-2-pick-and-tell  Y6ZNXABP31FUVQ8    45531  story-in-sequence
#
#    worker_arranged_photo_order  \
# 0                            0
# 1                            1
# 2                            2
# 3                            3
# 4                            4
# 5                            0
# 6                            1
# 7                            2
# 8                            3
# 9                            4
#
#                                                 text storylet_id
# 0    the local parish holds a craft show each year .      227650
# 1  lots of folks come out and set up tables to se...      227651
# 2  some of these crafts are very unique and take ...      227652
# 3  folks of all ages come out to peruse the craft...      227653
# 4  some of the crafters even dress up in unique c...      227654
# 5  i was so excited to be heading to the crafts f...      227655
# 6  when i arrived i saw a great booth with a vari...      227656
# 7  i stopped at chatted at my friend [female] 's ...      227657
# 8  there were even booths set up for all of the k...      227658
# 9  i found some awesome crafts at the fair , i 'm...      227659

# %%
# DataFrame の text に含まれる数字を文字列に変換
sis_test_annotations_df["text"] = sis_test_annotations_df["text"].apply(
    convert_numbers_to_words
)
dii_test_annotations_df["text"] = dii_test_annotations_df["text"].apply(
    convert_numbers_to_words
)

# %%
grouped = (
    sis_test_annotations_df.sort_values(["story_id", "worker_arranged_photo_order"])
    .groupby("story_id")
    .apply(lambda df: {row["photo_flickr_id"]: row["text"] for _, row in df.iterrows()})
    .to_dict()
)
grouped
# Out:
# /tmp/ipykernel_3847387/3546181835.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda df: {row['photo_flickr_id']: row['text'] for _, row in df.iterrows()})
# {'45530': {'1741642': 'the local parish holds a craft show each year .',
#   '1741640': 'lots of folks come out and set up tables to sell their crafts .',
#   '1741632': 'some of these crafts are very unique and take a lot of talent to make .',
#   '1741622': 'folks of all ages come out to peruse the crafts for sale .',
#   '1741587': 'some of the crafters even dress up in unique costumes as part of their selling act .'},
#  '45531': {'1741625': 'i was so excited to be heading to the crafts fair .',
#   '1741640': 'when i arrived i saw a great booth with a variety of great crafts .',
#   '1741639': "i stopped at chatted at my friend [female] 's booth for a bit .",
#   '1741633': 'there were even booths set up for all of the kids .',
#   '1741630': "i found some awesome crafts at the fair , i 'm really happy that i went ."},
#  '45532': {'1741642': 'the church is old , but it has a nice history .',
#   '1741640': 'they display this history during the afternoon .',
#   '1741632': 'some books even talk about location .',
#   '1741622': 'the older members of the church remember these things .',
#   '1741587': 'it makes them sad .'},
#  '45533': {'1741625': 'the people arrived to get ready for the craft fair .',
#   '1741640': 'the various merchants set up their booths .',
#   '1741639': 'the different merchants got together to talk before people began to arrive .',
#   '1741633': 'even the kids got to make some crafts .',
#   '1741630': 'everyone is set up and ready for the craft fair .'},
#  '45534': {'1741642': 'the annual victorian craft fair was hosted at the parish church of location location and organization organization again this year .',
#   '1741640': 'vendors came from all over the state to show off their crafts .',
#   '1741632': 'there was a large variety of pictures and decor .',
#   '1741622': 'even mr [male] made an appearance .',
#   '1741587': 'he brought along one of his bird toys to wow the visitors . everyone always loves him .'},
#  '45535': {'355137': 'the family takes a trip to the local carnival .',
#   '355139': 'there are lots of rides to enjoy this year .',
#   '355142': 'there are even rides for folks as young as this small boy .',
#   '355331': 'there are also lots of games and prizes to win .',
#   '355332': 'although some of the games seem fixed and a waste of money .'},
#  '45536': {'355204': 'mom decided to take her daughter to the carnival .',
#   '355205': 'they rode a lot of rides .',
#   '355208': 'their favorite was the dragon ship .',
#   '355331': 'then they spent some time trying to win stuffed animals .',
#   '355332': 'it was a great day !'},
#  '45537': {'355204': 'we had an exciting day at the fair !',
#   '355205': 'the lights lit up the night and the rides made us all dizzy .',
#   '355208': "the dragon coaster was mom 's favorite .",
#   '355331': 'the arcade games had the funniest stuffed monkeys as prizes .',
#   '355332': 'we threw a million darts trying to win one !'},
#  '45538': {'355137': 'the family got together to go to the fair .',
#   '355139': 'when they arrived they saw some airplanes in the back of a truck .',
#   '355142': 'the kids had a hard time deciding what to ride first .',
#   '355331': 'then they played some games to win prizes .',
#   '355332': 'finally they played the dart game .'},
#  '45539': {'355204': '[female] and [female] are having a great time at the carnival on the rides .',
#   '355205': 'whoa , exclaims [female] and [female] as the ride speeds up and goes faster .',
#   '355208': 'now onto the dragon ride . [female] and [female] are having a blast .',
#   '355331': '[female] tries to win a stuffed prize for [female] . she knows that [female] loves monkeys .',
#   '355332': '[female] and [female] notice another family playing another type of prize game and decides to try it out when they are finished before leaving the carnival .'},
#  '45540': {'21725505': 'the japanese tech show had toys and gadgets for everyone .',
#   '21728852': 'a robot that looked like a seal was used for autism research .',
#   '21731442': 'segways were redesigned to be more efficient .',
#   '21734444': 'pint sized robots roamed the tables .',
#   '21728853': 'and child sized robots left everyone in awe .'},
#  '45541': {'21725505': 'checking out a car at the car show',
#   '21725502': 'the cat is is laying on the table next to two crystal shot glasses',
#   '21725504': 'a modern compact type of boat at a display that resembles a plane',
#   '21728853': 'a boy happily standing next to a robot a display',
#   '21725506': 'stirring the big bowl of soup in a colorful bowl with a red spoon'},
#  '45542': {'21725505': 'we went to a science show and saw some of the new inventions .',
#   '21728852': 'including some stuffed animals .',
#   '21731442': 'segways were everywhere .',
#   '21734444': 'there were also robots .',
#   '21728853': 'some of the robots were as big as children .'},
#  '45543': {'21725505': 'we went to an technology show .',
#   '21728852': 'they had some unusual things .',
#   '21731442': 'my dad liked this scooter thing .',
#   '21734444': 'there were lots of small robots .',
#   '21728853': 'there were some bi robots too .'},
#  '45544': {'21725505': "today 's convention involved a bunch of new technology .",
#   '21728852': 'electronic seals dazzled the attendees .',
#   '21731442': 'a man on a segway showed off some tricks he had been working on for years .',
#   '21734444': 'a small robot stood on a table and talked trash to people walking by .',
#   '21728853': 'an even bigger robot walked around taking pictures with attendees until it was shut down .'},
#  '45545': {'2835098587': 'the family sits together for dinner on the first night of the annual reunion .',
#   '2835095703': 'the restaurant we chose had amazing food and everyone loved the presentation .',
#   '2835084931': 'gemma really adored the restaurants decorations and was always gazing at them .',
#   '2835924200': 'aunt harriot had a little trouble deciding what kind of wine she wanted tonight .',
#   '2835079599': '[male] had the whole family cracking up with his jokes .'},
#  '45546': {'2835917750': 'the family reunion had plenty of long-awaited greetings to start .',
#   '2835923100': 'eventually , we all filled each other in with deep conversation ...',
#   '2835931462': 'some of us were quite happy to see one another .',
#   '2835095703': 'of course , we filled our bellies with hearty food .',
#   '2835098587': 'what better way to celebrate family than over a delicious meal ?'},
#  '45547': {'2835098587': 'we all got together for my parents aniversary .',
#   '2835095703': 'we had amazing steak to celebrate .',
#   '2835084931': 'we had a few making speeches and be funny .',
#   '2835924200': 'there was a few sentimental moments thrown in .',
#   '2835079599': 'then it quickly turned funny again .'},
#  '45548': {'2835098587': 'a look down the table at our family gathering .',
#   '2835095703': 'the food looked amazing at the meal .',
#   '2835084931': 'mom and dad seemed to be having a wonderful time .',
#   '2835924200': '[female] starred deeply into the wine bottle .',
#   '2835079599': 'dad cracked one of his famous dirty jokes .'},
#  '45549': {'2835098587': 'it was a family get together .',
#   '2835095703': 'they even had fancy nice steak and tacos .',
#   '2835084931': '[female] laughs at a joke her sister told her .',
#   '2835924200': 'the family is having a wonderful time together .',
#   '2835079599': 'sharing so many memories and laughs together .'},
#  '45550': {'2485114971': "today i painted [female] 's fingernails .",
#   '2485114341': 'then she got to blow out her birthday candles and eat cake !',
#   '2485854685': 'later on we looked at her old baby pictures .',
#   '2485855255': 'she loved this one of her making her angry face .',
#   '2485855917': 'this was her favorite though . she thought she looked like a princess . we sat looking at old pictures eating cake for the rest of the evening .'},
#  '45551': {'2485114971': 'my daughter had her nails painted .',
#   '2486729724': 'we went for a walk down the beach .',
#   '2485114341': 'it was her birthday that day so we got her a big cake .',
#   '2485855255': 'she made a duck-face which made us think she was angry .',
#   '2485855917': 'in reality , she was happy .'},
#  '45552': {'2485114971': 'started the day off by painting her nails .',
#   '2486729724': 'enjoying the beach with her father and brother .',
#   '2485114341': 'blowing out the candles of her birthday cake .',
#   '2485855255': 'birthday girl having a moment of anger .',
#   '2485855917': 'her face quickly changes to a smile .'},
#  '45553': {'2485114971': "we painted liz 's fingernails and toenails before her party , and she wore her nice new clothes .",
#   '2485114341': 'when the party happened , she was most excited about her cake .',
#   '2485854685': 'later that day we tried to take her picture , but she kept making funny faces .',
#   '2485855255': "she was a little tired , and did n't want her picture taken .",
#   '2485855917': 'we did get one great shot , though .'},
#  '45554': {'2485114971': "the family decided to take a beach vacation to celebrate their daughter 's birthday . up first : pedicures !",
#   '2486729724': 'dad and the kids took a walk under the boardwalk while mom decorated .',
#   '2485114341': 'the girl blew out her candles and made a wish .',
#   '2485855255': 'but the puppy she wished for never showed . this made her sad .',
#   '2485855917': 'she cheered up after opening up presents .'},
#  '45555': {'14443472923': 'we went to the stadium early to eat and sight see before the game .',
#   '14443473773': 'the view was incredible . you could see the entire city .',
#   '14236702198': "we got to our seats , and could n't believe how close to the field they were",
#   '14236701078': 'we could see all the action .',
#   '14423296985': 'once the national anthem was sung , and the first pitch was thrown , the excitement began . it was a great game !'},
#  '45556': {'14423298935': 'i took the family to a baseball game and we saw this awesome car before the game , that you had a chance to win in a raffle .',
#   '14422160704': 'we were lucky enough to get to the game early and our seats were amazing .',
#   '14419942051': 'of course we had to get a family selfie during the game .',
#   '14423296985': 'the scoreboard was so huge , i had to get a photo of it .',
#   '14236654939': 'the girls loved being so close to the field that they could reach out and touch the ground if they wanted to .'},
#  '45557': {'14443472923': 'we got to go to the stadium for an organization game .',
#   '14443473773': 'we posed by the window .',
#   '14236702198': 'the family posed by the field .',
#   '14236701078': 'we were very close .',
#   '14423296985': 'the scoreboard could be clearly seen .'},
#  '45558': {'14443472923': 'the whole family went to the stadium on thursday .',
#   '14443473773': 'the daughter was especially excited to see the baseball game .',
#   '14236702198': 'it was a good opportunity for them to spend time together and have fun .',
#   '14236701078': 'many people were there at the stadium , and everybody was just as excited as the family .',
#   '14423296985': 'as the scoreboard showed , it was a close game , which made it even more fun to watch .'},
#  '45559': {'14443472923': 'we had a great view of location location location from our hotel room .',
#   '14443473773': 'we took a picture of our daughter with the park .',
#   '14236702198': 'later at the game we took a family picture .',
#   '14236701078': 'i then took a panorama picture inside .',
#   '14423296985': 'the organization ended up winning the game .'},
#  '45560': {'2582414424': 'i got this great , new bike for my birthday !',
#   '2582415688': 'i am so excited i am going to ride it everywhere i can in one day .',
#   '2582423982': 'i will ride it threw the woods and down the road .',
#   '2582423092': 'i will ride it to the lake , okay , that was exhausting .',
#   '2582414024': "i think i 'll take a nap and ride my bike some more tomorrow ."},
#  '45561': {'2582417232': 'he wanted to take a ride on his new bike .',
#   '2582414424': 'we went on a nice ride out to the lake .',
#   '2581592241': 'we really enjoyed the beautiful view from the dock .',
#   '2581594339': 'it was very peaceful watching the boats .',
#   '2582414024': 'we had such a busy day he needed a nap .'},
#  '45562': {'2582414424': '[male] and i went out for a bike ride .',
#   '2582415688': '[male] believes that he will become the next greatest bike rider .',
#   '2582423982': '[male] was going so fast here , he was like a rocket !',
#   '2582423092': 'he came to the pier first , and so we had to buy pizza .',
#   '2582414024': 'he was going so fast , he slept like a dear !'},
#  '45563': {'2582414424': 'i bought my son a new bicycle for his birthday .',
#   '2582415688': 'he spent the afternoon riding it up and down the road .',
#   '2582423982': 'he rode it pretty far into a wooded area .',
#   '2582423092': 'then he rode it out to the docks and stopped to watch the boats on the water .',
#   '2582414024': 'all that riding tired him out and he fell asleep on our car ride back home .'},
#  '45564': {'2582414424': 'today we went for a long bike ride through the park .',
#   '2582415688': 'the boy led the way and i followed behind .',
#   '2582423982': "he was full of energy and could n't stop exploring the park .",
#   '2582423092': 'he made it to the dock and decided that was a good place to end the journey .',
#   '2582414024': 'he must have tired himself out because he fell asleep as soon as we got in the car !'},
#  '45565': {'2580735309': 'we took the boat out for a ride on the lake .',
#   '2580742595': 'we all piled on for a great conversation and had a few drinks .',
#   '2581572326': 'the captain of this ship is so young , just a baby really .',
#   '2580753271': "we went by a cabin on the lake , maybe we 'll rent that for our next vacation .",
#   '2580757505': "every body had a great time and ca n't wait to do it again ."},
#  '45566': {'2581560296': 'my name is [male] . i am a happy baby',
#   '2581565132': 'this is my grandpa alvin . we always have a good time when we get together',
#   '2580742595': 'this is my dad . my dad like sto take me to the park',
#   '2581572326': 'in the park we sit outside and watch the people and the boats in the lake',
#   '2581576824': 'i am really tired from my day in the park . my dad says i can take a nap now .'},
#  '45567': {'2580735309': 'last weekend we decided to ride our motorboat with my parents so they can see their grandchild , [male] .',
#   '2580742595': 'this is me on the right with my parents , [male] and [female] before the ride .',
#   '2581572326': 'grandpa steered the motorboat with my son [male] on his lap .',
#   '2580753271': 'we enjoyed the relaxing ride on the motorboat as we passed by some houses along the river .',
#   '2580757505': 'it was a relaxing trip and what abetter way to bond with my parents on that saturday afternoon .'},
#  '45568': {'2580735309': 'boating on the lake with family',
#   '2580742595': 'relaxing on the boat',
#   '2581572326': 'let baby drive for a while .',
#   '2580753271': 'we spotted the lodge .',
#   '2580757505': 'and headed back to shore .'},
#  '45569': {'2580735309': "we took a trip out on the lake in uncle [male] 's new boat on thursday .",
#   '2580742595': 'uncle [male] , aunt [female] , and aunt [female] relaxed in the back drinking beers .',
#   '2581572326': 'grandpa drove with little [male] on his lap while his parents looked on .',
#   '2580753271': 'we passed the house where grandpa used to live and he pointed it out to us .',
#   '2580757505': 'it was great to spend time with family !'},
#  '45570': {'2582165707': 'our first stop at the local carnival was the face painting booth .',
#   '2582174211': 'once mine was done , mom got one , too and then we stood and watched my daughter get hers done .',
#   '2583010022': 'she picked a really cute face and we hardly recognized her afterwards .',
#   '2582191447': 'next we looked at crafts while the kids were entertained by the balloon lady .',
#   '2583021318': 'the balloon lady was face painted as a clown and the kids loved her .'},
#  '45571': {'2582195345': 'the whole family visited a local fair .',
#   '2582996500': 'grandpa was smiling for the photo .',
#   '2582188675': 'dad doing his best to stay cool in the shade .',
#   '2582206265': 'the kids enjoyed getting their faces painted .',
#   '2582214197': 'mother and son together .'},
#  '45572': {'2582165707': 'we were at the fair at a booth .',
#   '2582174211': 'me and my friend both had our faces painted .',
#   '2583010022': 'my little sister had a tiger painted on her .',
#   '2582191447': '[male] was sitting in a chair by himself .',
#   '2583021318': 'he posed with this lady .'},
#  '45573': {'2582165707': 'i love going to the art fest .',
#   '2582174211': 'me and my mom got our faces painted .',
#   '2583010022': 'my daughter was transformed with the face paint .',
#   '2582191447': 'so many people had booths there .',
#   '2583021318': 'my husband even had a good time'},
#  '45574': {'2582165707': 'every year when we go to the fair , i always love seeing all the face painting .',
#   '2582174211': "the adults are n't afraid to look a little silly .",
#   '2583010022': 'and the kids like to go all-out by getting their whole face covered in paint .',
#   '2582191447': 'this year there was also a glass artist .',
#   '2583021318': "and he was n't afraid to be a little silly , too , because here he is with a clown ."},
#  '45575': {'2586798951': 'jimmy is walking up to the group of people at the farm',
#   '2583415536': 'the pigs are anxiously awaiting jimmys arrival as well',
#   '2583415780': 'jeff doesnt want to hear matt keep asking when jimmy will be there ! !',
#   '2583416512': 'off int he fireld they see the shape of a man and realize jimmy is there ! !',
#   '2583416580': 'the girls are really happy to see thier friend'},
#  '45576': {'2582586039': 'we went to a vineyard for the holiday weekend .',
#   '2583415536': 'there were pigs there ! it was my first time seeing such pigs .',
#   '2583416080': "our friend wore a funny hat that caught everyone 's attention .",
#   '2582587033': 'he was the subject for many jokes .',
#   '2582587409': 'later , we all gathered at the long table to eat and drink wine .'},
#  '45577': {'2586798951': 'today we visited a farm .',
#   '2583415536': 'we spotted some pigs .',
#   '2583415780': 'at the table , my brother and i jokes around .',
#   '2583416512': 'the windmills were spinning .',
#   '2583416580': 'we got on a hayride and had a great time .'},
#  '45578': {'2586798951': '[male] thought it would be funny to play with the local pigs with his new toy .',
#   '2583415536': 'the pigs were annoyed by the bubbles and started to squeal loudly at the commotion [male] caused .',
#   '2583415780': "[male] 's friends could n't stand the loud pig noises and told him to stop .",
#   '2583416512': 'to escape the pig noises , [male] and his friends decided to travel along the farmland , but got lost in a field of plants .',
#   '2583416580': 'they met up with two woman who were also lost in the field and the two groups had no choice but to survive together until help could arrive .'},
#  '45579': {'2586798951': 'hi . every summer we head out midwest to location to visit my relatives and experience country life .',
#   '2583415536': "here we see my cousin 's pigs and are they huge and noisy pigs .",
#   '2583415780': 'these are my cousins having a fun moment with each other .',
#   '2583416512': 'while it was hot and humid , we really enjoyed the country view with less noise and traffic and no buildings .',
#   '2583416580': 'and these are my friends and relatives while we check out the produce of their farm .'},
#  '45580': {'14428427866': 'the guys sit down to a few beers at the table',
#   '14450429844': 'it looks like they may be up to some cards .',
#   '14450195182': 'she spends some time with the young baby .',
#   '14471723603': 'a black dog comes around to enjoy the day .',
#   '14265114507': 'maybe he smelled the delicious crabs being cooked .'},
#  '45581': {'14450437184': 'our family recently got together to cook out and eat some crabs .',
#   '14264906769': 'this was the first time i ever got to hold a crab .',
#   '14450198742': 'most of us ate them outside in the backyard .',
#   '14264961198': 'some could not stand the heat and ate them inside on the deck .',
#   '14265872990': 'our cat smells something fishy and decided to see what was going on .'},
#  '45582': {'14428427866': 'we invited the family over for a crab boil .',
#   '14450429844': 'the kids sat around , useless as usual , as the adults did the work .',
#   '14450195182': 'my mother sat with the baby most of the time .',
#   '14471723603': 'the dog got antsy and started sniffing around for food .',
#   '14265114507': 'then we loaded the crabs in the pan and prepared them for cooking .'},
#  '45583': {'14428427866': 'their dad is there ring leader .',
#   '14450429844': 'he gathers the guys around out back .',
#   '14450195182': 'his mom babysits while he conducts the meetings .',
#   '14471723603': 'the dog watches guard to make sure no one interrupts',
#   '14265114507': 'they about using crabs for protection also .'},
#  '45584': {'14428427866': 'we had a blue crab boil .',
#   '14450429844': 'everybody got to talk with each other while cracking open crabs .',
#   '14450195182': 'mom got to see our baby too .',
#   '14471723603': 'the dog tried to steal some crab to eat .',
#   '14265114507': 'we had dozens of blue crab to eat .'},
#  '45585': {'5276683392': 'our western location road trip took us to some amazing places .',
#   '5276073257': 'we went to an old western pueblo .',
#   '5276072677': 'we visited some random towns we had never heard of .',
#   '5271438744': 'we rode into organization , and decided to stay here for the night .',
#   '5271445558': 'we found a great cantina , and ate tacos and drank some beer before retiring to the hotel .'},
#  '45586': {'5276072677': 'i finally arrived at zuni !',
#   '5271438744': 'i stayed there all the way until it was night time .',
#   '5270830727': 'when it was dark , i wanted to explore the city .',
#   '5271440558': 'unfortunately , it was extremely empty for some reason .',
#   '5271445558': 'i ended up getting a drink at a local cafe .'},
#  '45587': {'5276683392': 'we were on a road trip .',
#   '5276073257': 'we stopped by the pueblo .',
#   '5276072677': 'then we went to zuni .',
#   '5271438744': 'we snapped a pic of this .',
#   '5271445558': 'after a long time of driving we had to stop at a cafe to get something to eat .'},
#  '45588': {'5276683392': 'we are on our way to location . look how low the clouds hang .',
#   '5276073257': 'this pueblo of zuni sign made me feel like i was in the location location .',
#   '5276072677': 'we are officially entering into location and so is the rain .',
#   '5271438744': 'the winds were so strong during the storm , this sign was blown over',
#   '5271445558': 'we stopped in for some mexican , american food to end the night .'},
#  '45589': {'5276072677': 'a group of friends decided to take a road trip through location location .',
#   '5271438744': 'they stopped in a town called location .',
#   '5270830727': "it was n't very lively out , despite being friday night .",
#   '5271440558': 'they walked around looking for a place to eat .',
#   '5271445558': 'they finally found an open cafe and had some mexican-american grub .'},
#  '45590': {'5853218453': 'when we finally brought our son home from the hospital so many people were at home with us to see him .',
#   '5853771226': 'everyone wanted a chance to hold him !',
#   '5853772178': 'we were all so happy to have a new addition to the family .',
#   '5853773180': 'my parents were so proud to be grand parents !',
#   '5853775370': 'i am so happy and i love my son very much !'},
#  '45591': {'5853771226': 'everyone was really excited when we brought the baby home .',
#   '5853771632': 'they all wanted to see and hold him .',
#   '5853772178': 'he was very popular .',
#   '5853222289': 'the entire family had come to see him .',
#   '5853775370': 'we are very glad to be parents .'},
#  '45592': {'5853218453': 'my mother introduced my nephew to his newest cousin not long after he was born .',
#   '5853771226': 'my grandmother then held him as my mother took my nephew for a bath .',
#   '5853772178': 'next was my father , who looked a bit awkward holding him .',
#   '5853773180': 'they soon gave him back to me when he started crying . i got him to stop and sleep .',
#   '5853775370': 'he slept in my arms the rest of the night .'},
#  '45593': {'5853218453': 'people are sitting on the floor .',
#   '5853771226': 'a grandmother is holding her grandchild .',
#   '5853772178': 'a man is holding a baby .',
#   '5853773180': 'a family is holding a baby .',
#   '5853775370': 'a man is holding his child .'},
#  '45594': {'5853218453': 'my sister had a baby',
#   '5853771226': 'the whole family came over to meet him',
#   '5853772178': 'my father is a grandfather for the first time',
#   '5853773180': 'and my grandparents are great grandparents now',
#   '5853775370': 'daddy loves his child'},
#  '45595': {'2688787325': 'the family is having a party in the park .',
#   '2688792633': '[male] wonders who has the ball .',
#   '2688793679': '[female] is ready for action .',
#   '2688793245': "[male] 's waiting for the baseball to come his way .",
#   '2688786489': 'everyone is too tired to pack up and go home .'},
#  '45596': {'2688786489': 'this afternoon , the baseball team had a practice game on the field .',
#   '2688787325': 'coaches and parents sat in lawn chairs and observed from afar .',
#   '2688789159': 'our resident photographer had brought along his camera .',
#   '2688789659': 'the coach wore sunglasses to shield his eyes from the bright sun .',
#   '2688793679': 'meanwhile , out on the field , the players were working hard .'},
#  '45597': {'2688787325': 'we set up our chair for the softball game .',
#   '2688792633': 'they were getting ready to play . the ball was thrown .',
#   '2688793679': 'she ran to catch the ball .',
#   '2688793245': 'our team scored a point .',
#   '2688786489': 'we enjoyed relaxing and watching the game .'},
#  '45598': {'2688787325': 'people gathered to watch their families play a game together .',
#   '2688792633': 'a lady waited for the ball to come to her .',
#   '2688793679': 'another girl was ready to play .',
#   '2688793245': 'one man had waited a long time to be able to show his family how much skill he had .',
#   '2688786489': 'everyone had a great time watching .'},
#  '45599': {'2688787325': 'everyone gathered for game day .',
#   '2688792633': 'my husband stood with his mitt , upset by the score .',
#   '2688793679': 'my coworker was really into the game .',
#   '2688793245': 'while others just stood in the field .',
#   '2688786489': 'i sat in my chair laughing at the game .'},
#  '45600': {'3144668424': 'our family recently went out together for a meal .',
#   '3144664688': 'this dish was my favorite since i really like noodles .',
#   '3144666540': 'there was a plate of meat for those that liked that .',
#   '3143846721': 'i took a lot of pictures and got some good ones .',
#   '3144675790': 'i like this photo where they were trying hard to be comical .'},
#  '45601': {'3144651580': 'mother and child are happy .',
#   '3143850391': 'something funny is going on .',
#   '3143835903': 'the little one has no idea .',
#   '3144658124': "someone 's in for a surprise .",
#   '3144668424': "maybe we 'll find out over dinner ."},
#  '45602': {'3144668424': 'the family all gathered around for dinner .',
#   '3144664688': 'we made some noodles .',
#   '3144666540': 'we also had tariyaki chicken .',
#   '3143846721': '[female] pulled out the organization .',
#   '3144675790': 'they joked around as she snapped some pictures .'},
#  '45603': {'3144668424': 'family night , tonight we chose our favorite restaurant .',
#   '3144664688': 'it has our favorite dishes .',
#   '3144666540': 'we often fight over this dish if it is the last one available .',
#   '3143846721': "and our cousin ca n't help herself , but we usually run when we see her with her camera !",
#   '3144675790': "or we make faces ! we had a great night . ca n't wait till next month ."},
#  '45604': {'3144668424': 'the whole family gathered for dinner .',
#   '3144664688': 'there was lots of food .',
#   '3144666540': 'we made some wonderful traditional dishes .',
#   '3143846721': 'mom took lots of photos .',
#   '3144675790': 'everyone was posing for her .'},
#  '45605': {'1802273989': 'in location we do fund raising with a difference !',
#   '1803117082': 'welcome to the first annual prostrate cancer prevention triathlon ! first you will do a five meter dash to the first food tent .',
#   '1802274693': 'the tent is crowded so please be patient . remember , you are eating for a cause .',
#   '1802274513': 'once you finished your first meal , you will swim ten kilometers against the current in the location location . watch out for cramps !',
#   '1803118002': 'your reward ? a wonderful meal of location and pea meal bacon . also , you will be helping a very good cause .'},
#  '45606': {'1803118002': 'not the greatest breakfast but it will fill me up enough to give me energy .',
#   '1803115934': "here is the starting line ! woo hoo , i 'm gon na win this .",
#   '1802273787': 'breakfast tables of champions .',
#   '1802275571': 'here is my new shirt , i will cherish .',
#   '1803117082': "here is where i '' m gon na win this race ."},
#  '45607': {'1802273989': 'today we run for charity , this sign explains it all .',
#   '1803117082': 'you start on one side , you end on the other . it will be a great circle of a run .',
#   '1802274693': 'the competitors were all gathered , competition was in the air .',
#   '1802274513': 'the lake we were going to run around was pretty big and deep .',
#   '1803118002': 'before we raced however we ate a hearty meal .'},
#  '45608': {'1802273989': 'it was a rainy day but we still came out to raise money for prostate cancer treatment .',
#   '1803117082': 'finally i see the finish line . we walked and ran for a good cause .',
#   '1802274693': 'afterwards we gathered under a tent for some hot breakfast .',
#   '1802274513': 'while waiting for my breakfast i see ducks playing in the lake .',
#   '1803118002': 'my breakfast arrives just in time . bacon and french toast . my favorite .'},
#  '45609': {'1802273989': 'the community came out to support the prostate cancer awareness .',
#   '1803117082': 'the fund raising marathon has not started yet .',
#   '1802274693': 'the people gathered under the tent because it started to rain .',
#   '1802274513': 'the rain has caused the water to rise in the lake .',
#   '1803118002': 'the food prepared for the community consisted of bacon and pancakes .'},
#  '45610': {'20361801': "many people enjoyed meeting professional baseball players at today 's game .",
#   '20361837': 'the children were excited waiting in line to meet their heroes .',
#   '20361855': 'many families enjoyed spending time together while getting to meet their favorite baseball players .',
#   '20370589': 'a baseball player demonstrates his skill and catches the ball .',
#   '20370881': 'fans enjoyed the view of the game from the stands before this exciting day ended .'},
#  '45611': {'20370881': 'this is a stadium that we saw our favorite team play baseball .',
#   '20361855': 'they let us come on the field to meet some of the players .',
#   '20361829': "they even let me throw a pitch from the pitcher 's mound .",
#   '20370424': 'we saw how the baseball officials worked .',
#   '20370833': 'this was a great player that talked to us before we went home .'},
#  '45612': {'20370881': 'the audience watches closely as the baseball game begins .',
#   '20361855': 'the team poses for pictures the lucky fans .',
#   '20361829': 'some fans even get to pitch a baseball .',
#   '20370424': 'the catcher and the pitcher discuss game plans .',
#   '20370833': 'the pitcher walks to the dugout for a short break .'},
#  '45613': {'20370881': 'out on a family outing .',
#   '20361855': 'some of the kids posing on the field .',
#   '20361829': 'first pitch thrown for the game .',
#   '20370424': 'pitcher is getting ready .',
#   '20370833': 'off to the dugouts .'},
#  '45614': {'20361801': 'i got to go to my first baseball game .',
#   '20361837': 'we went onto the field before the game started',
#   '20361855': 'and got picture with some of the players .',
#   '20370589': 'the pitcher was on target .',
#   '20370881': 'the team i was routing for won .'},
#  '45615': {'20387243': "i 've got a cottage on the lake that i like to go to for vacations .",
#   '20389936': 'the lake is actually pretty big .',
#   '20386343': 'we also have a boat out there .',
#   '20384883': 'we usually build a campfire after the sun goes down .',
#   '20385743': 'we build the fire in the compost pile because ashes are good for the garden .'},
#  '45616': {'20384693': 'the fire burned in an angry and nasty biblical way .',
#   '20384883': 'the flames seemed to reached toward heaven .',
#   '20385159': 'the sky was gray , dark with clouds gathered from the smoke of the fire .',
#   '20385452': 'the fire as it appears to be loosing its power .',
#   '20385743': 'fire , still destructive and cruel , but appearing contained .'},
#  '45617': {'20387243': 'we stayed by a lake .',
#   '20389936': 'the lake was very calm .',
#   '20386343': 'we decided to take a boat ride out .',
#   '20384883': 'later that evening , we built a fire .',
#   '20385743': 'we just sat and relaxed around it .'},
#  '45618': {'20387243': 'the lake house had a little dock for the boat .',
#   '20389936': 'the water was very still that day .',
#   '20386343': 'we went out on the jet skis .',
#   '20384883': 'at night , we light a fire and hung out .',
#   '20385743': 'the fire burnt great and we even cooked a bit on it .'},
#  '45619': {'20384693': 'i went down to the beach last weekend .',
#   '20384883': 'there was a big fire there .',
#   '20385159': 'the storm clouds were also coming in .',
#   '20385452': 'i spent some time at the beach .',
#   '20385743': 'after a few hours i left to go home .'},
#  '45620': {'20403686': 'we went to the beach on holiday .',
#   '20402942': 'it was a beautiful day , and i saw nature like i had never seen it before .',
#   '20404109': 'during lunchtime we went to a local cafe and enjoyed the ambiance .',
#   '20403298': 'we saw some of the local artistry on the way back to the beach .',
#   '20403325': 'it was a gorgeous day to spend with family .'},
#  '45621': {'20403077': 'everyone was excited to be going on vacation .',
#   '20403190': 'we stopped at a memorial and spent our time reading about the history of it .',
#   '20403474': 'it was fourth of july that day , we were proud to be americans .',
#   '20403542': 'we decided to go on a diving trip , it seemed exciting .',
#   '20403520': 'we spent the rest of the day on the water , it was a great day !'},
#  '45622': {'20403077': 'we went on a tour of location location',
#   '20403190': 'we visited some of the monuments',
#   '20403474': 'we saw the big american flag',
#   '20403542': 'there were even some scuba divers that were going to do testing',
#   '20403520': 'it was neat seeing them go into the location like that'},
#  '45623': {'20403686': 'he was inspired by the ducks .',
#   '20402942': 'he liked the way the sand that had washed looked .',
#   '20404109': 'at lunch he drew a sketch .',
#   '20403298': 'he would hang the painting in the other window like this one .',
#   '20403325': 'once he got done , they could hang out down by the shore .'},
#  '45624': {'20403686': 'the water was calm',
#   '20402942': 'near the shore .',
#   '20404109': 'the people laughed',
#   '20403298': 'at the window',
#   '20403325': 'and then they laid out .'},
#  '45625': {'29208812': 'i went on a nature hike with my dad and my brother .',
#   '29208531': 'we eventually ran across this creek .',
#   '29208415': 'there was a huge boulder right in the middle of the stream .',
#   '29208494': 'my dad joked about diving off .',
#   '29209380': 'i used the self timer and got a picture of us all together .'},
#  '45626': {'29208415': 'my dad and i went hiking last weekend .',
#   '29208812': 'we went through some amazing valleys .',
#   '29208949': 'the mountains had gorgeous rocks on them .',
#   '29209313': 'there were hidden rivers all over the place .',
#   '29209380': 'we met up with our friend before going home to eat .'},
#  '45627': {'29208812': 'taking a hike in the beautiful mountain side .',
#   '29208531': 'loving the flow of the creek , very relaxing .',
#   '29208415': 'my dad and husband standing by a rock .',
#   '29208494': 'dad acting like he was going to dive in creek .',
#   '29209380': 'beautiful generation of wonderful men with an amazing background .'},
#  '45628': {'29208812': 'a father and sons went camping on a mountain trail .',
#   '29208531': 'they saw a beautiful river .',
#   '29208415': 'they took pictures by large rocks .',
#   '29208494': 'they stood on boulders .',
#   '29209380': 'the other put his arms around his sons .'},
#  '45629': {'29208812': "people who do n't appreciate nature absolute baffle me .",
#   '29208531': 'a babbling brook is more pleasant and calming than anything else in the world .',
#   '29208415': 'i often go on hikes with my father .',
#   '29208494': 'my dad taught me everything i know about surviving in the wilderness .',
#   '29209380': 'after a lot arm twisting , we got my brother to come along on our last hike .'},
#  '45630': {'171285332': "here 's the family eating food , it 's delicious .",
#   '171285357': "they are all so family oriented that they did n't realize that their is n't enough chairs !",
#   '171285457': 'they all encourage to eat as much food as possible , even the kid has a sippy cup .',
#   '171285527': 'some people need a break from eating too much food .',
#   '171285930': 'some people like to read after eating too much !'},
#  '45631': {'171285717': 'a young boy watched his dad and grandpa work on a backyard project .',
#   '171285357': 'after they finished their project , the family sat down to a meal .',
#   '171285417': 'there was potatoes , beef , and rice .',
#   '171285930': 'full from all of the food , they sat on the couch to look at family pictures .',
#   '171285527': 'two members were so exhausted from the long day that they fell asleep in their chairs .'},
#  '45632': {'171285717': 'at the family gathering , some yard maintenance needs to get done .',
#   '171285357': 'the family sits at the table inside to eat together .',
#   '171285417': 'the dinner is steak , potatoes and a side dish .',
#   '171285930': 'after dinner is story time and the kids listen closely .',
#   '171285527': 'a nap is necessary after a long day .'},
#  '45633': {'171285717': 'the guys working in the yard before dinner .',
#   '171285357': 'our sunday family dinner .',
#   '171285417': 'plenty to go around .',
#   '171285930': 'decided to read the kids a story after dinner .',
#   '171285527': 'she kept him up late last night .'},
#  '45634': {'171285717': 'we got together for a family barbeque .',
#   '171285357': 'we set up the table and made the food .',
#   '171285417': 'it looked absolutely amazing .',
#   '171285930': 'afterwards we went through some family albums .',
#   '171285527': 'then passed out from being so full .'},
#  '45635': {'171268203': 'we hosted a fourth of july party at our home .',
#   '171267971': 'i got to use my new grill .',
#   '171122565': 'the food came out delicious .',
#   '171267521': 'the kids got to splash around all day .',
#   '171270427': "by the day 's end , we were exhausted ."},
#  '45636': {'171268454': 'the young boy wanted to come outside .',
#   '171270190': 'dad plays by pretending to throw him in the pool .',
#   '171269804': 'mom actually does dunk the boy in the kiddie pool .',
#   '171267971': 'grand dad is working the grill .',
#   '171122565': 'the grilled chicken went well with a cold hard lemonade .'},
#  '45637': {'171268203': 'it was time for our picnic .',
#   '171267971': 'grandpa did the grilling .',
#   '171122565': 'the chicken was delcious .',
#   '171267521': 'then we went for a dip in the pool .',
#   '171270427': 'what an awesome day it was .'},
#  '45638': {'171268203': 'our fourth of july barbecue was the best .',
#   '171267971': 'dad ruled over the grill like a master .',
#   '171122565': "there was n't much food left at the end of the day .",
#   '171267521': 'the kiddie pool was a perfect place to cool your feet on a hot summer day .',
#   '171270427': "someone had so much fun , they did n't want to go to bed after their shower ."},
#  '45639': {'171268203': 'we had a party to celebrate july fourth this weekend .',
#   '171267971': 'grandpa was in charge of the grill .',
#   '171122565': 'the food was great and most of it was gone real fast .',
#   '171267521': 'mom loved catching up with aunt [female] .',
#   '171270427': 'i love hanging out with my dad .'},
#  '45640': {'559044099': 'the barbecue cookout was lots of fun .',
#   '559044193': 'it was at a really popular fishing spot .',
#   '558750494': 'this truck had tons of advertisements on it .',
#   '559044997': 'there was plenty of buns to go around .',
#   '559044851': 'the corn barbecuing was the best part .'},
#  '45641': {'558751470': 'the stands for the ball game were packed .',
#   '559044099': 'the mascots were ready to go .',
#   '558750890': 'fans watched the scoreboard closely .',
#   '558751752': 'it was a very close game .',
#   '559046145': 'in the end , we won !'},
#  '45642': {'559044099': 'mascot meeting before the game .',
#   '559044193': 'everyone picked the player they thought would do the best .',
#   '558750494': 'the pitcher was voted the number one .',
#   '559044997': 'he got ready to throw the ball .',
#   '559044851': 'then stopped and changed his mind .'},
#  '45643': {'558751470': 'thousands of people went to the ball game .',
#   '559044099': 'the show before the game was extremely entertaining .',
#   '558750890': 'i was anxious for the game to start though .',
#   '558751752': 'i had a lot of money riding on the final score .',
#   '559046145': 'thankfully , my team won , and i did too !'},
#  '45644': {'558751470': 'this is the largest turn out this year for a baseball game .',
#   '559044099': 'i just love the mascots uniforms .',
#   '558750890': 'aunt [female] is wondering when the game will start .',
#   '558751752': 'this game is going to be a close one .',
#   '559046145': 'what is baseball with out the arguments ?'},
#  '45645': {'562553404': 'yo yo yo . i got a story for you today .',
#   '562514728': 'there was this zebra named zeeb . he was just minding his business when he bumped into his enemy , white bear .',
#   '562786159': 'white bear started at him and was like yo you got a problem ?',
#   '562559554': 'zeeb turned to him and was like , come at me bruh . zeeb looked super cool .',
#   '562798801': 'white bear noticed his cool and walked away . i was like wow i need to get some of my own stripe .'},
#  '45646': {'562768785': '[male] is cleaning out his train .',
#   '562786159': 'he then goes and sees his pet polar bear .',
#   '562427734': 'after seeing his pet polar bear a brown bear comes up to him .',
#   '562467436': 'then an owl comes from out of nowhere .',
#   '562520294': 'a zebra comes too !'},
#  '45647': {'562553404': 'we went to the zoo today and got to see so many animals',
#   '562514728': 'my son feel in love when we got to see the zebras',
#   '562786159': "i me myself i could n't wait to see the polar bears jump in the water and swim",
#   '562559554': 'we ended up making a second pass around the zebras for my son',
#   '562798801': 'so while my son went to look at the zebras i went back to enjoy more of the polar bears'},
#  '45648': {'562768785': 'a man was preparing the zoo for us .',
#   '562786159': 'once everything was ready , we saw a polar bear .',
#   '562427734': 'we also saw an oddly colored polar bear .',
#   '562467436': 'we were scared , and seeing an owl did not calm us .',
#   '562520294': 'we decided to leave but our path was blocked by a zebra .'},
#  '45649': {'562553404': 'we went to see the location location , and our first stop was some gazelle like animal',
#   '562514728': 'eventually we came to see the zebra , who is very majestic in his pasture',
#   '562786159': "when we came to the polar bear , i could n't help but see his moustache",
#   '562559554': "we went back to see the zebra again ; he 's my favorite animal . his mane is so cool",
#   '562798801': 'when we left the park later on we passed the polar bear , who gave us a smile as we departed'},
#  '45650': {'562782455': 'my son was excited to go to this first baseball game with his daddy .',
#   '562801667': 'the two of them had such a great time together at the stadium .',
#   '562987241': 'the best part of the day for them both was our team winning by a few homeruns !',
#   '562874643': 'after the game , he was able to go down on the field and play .',
#   '562539306': 'he was tired by the end of the day , but it is a day he will remember forever .'},
#  '45651': {'562782455': 'i went to the ball game with my family last week .',
#   '562792161': 'there were a lot of empty seats in the stands .',
#   '562801667': 'my dad was sitting next to me the whole time .',
#   '562804747': 'the game was very close .',
#   '562400126': 'the players were very good but there was a lot of downtime in between innings .'},
#  '45652': {'562782455': 'my dad took me to the baseball game because i made good grades .',
#   '562801667': 'here is me and my dad having a great time .',
#   '562987241': 'the game was very close here everyone was cheering .',
#   '562874643': 'my dad took me to the field to take some pictures it was awesome .',
#   '562539306': 'overall we had a great day at the game , here is the last picture on the field before we left .'},
#  '45653': {'562782455': 'the stadium was packed with people on the day of the game .',
#   '562801667': 'son and father alike , watched the players triumph over the other team .',
#   '562987241': 'they went all day , vying for the win .',
#   '562874643': "after the game , they got to run down onto the field , and see the place through the player 's eyes .",
#   '562539306': 'they both had a great time , and were glad they came .'},
#  '45654': {'562782455': "for father 's day , this young man took his father to a organization organization game .",
#   '562801667': 'they shared snacks before the game .',
#   '562987241': 'the game was fun and exciting .',
#   '562874643': 'afterward , the fans were allowed to come down to the field and meet some of the players .',
#   '562539306': 'and the young man caught an awesome souvenir .'},
#  '45655': {'563266319': 'the cake before it is devoured by the family .',
#   '562936876': 'lizzy wolfs down a piece of the delicious caek .',
#   '562904006': 'grandpa fixes one of the toys that girls broke .',
#   '562962784': 'the girls all ready to throw lizzy into the pool .',
#   '563342231': 'the more mature crowd sit and catch up around the table .'},
#  '45656': {'563281835': 'i love growing flowers in my garden , but there are a few instant favorite varieties of mine .',
#   '562919054': 'the white faded pink roses are some of the best in my collection of roses and they really blend in well with any color .',
#   '562993318': 'in truth though , the hot pink ones are not just another favorite , but one that people notice the most .',
#   '563408677': 'these beauties like to hide , but as my neighbor says , they hide because they are shy .',
#   '563069310': 'at times nature creeps in even more and i get a few animal visitors .'},
#  '45657': {'563281835': 'there are so many different flowers in my garden .',
#   '562919054': 'i like the white ones especially .',
#   '562993318': 'these are pink , and they are growing in great .',
#   '563408677': 'look how large the bush of flowers has gotten .',
#   '563069310': 'i even have some friendly animals hanging around .'},
#  '45658': {'563281835': 'the garden had a lot of beautiful flowers in it .',
# ...
#  '46490': {'3549332283': 'my brother recently graduated college .',
#   '3550160812': 'it was a formal cap and gown event .',
#   '3550171580': 'my mom and dad attended .',
#   '3549368069': 'later , my aunt and grandma showed up .',
#   '3549370593': 'when the event was over he even got congratulated by the mascot .'},
#  '46491': {'3549359579': 'today was graduation , and schyler was extremely happy .',
#   '3549346163': 'however he was nervous about what the future would bring .',
#   '3550171580': 'his parents assured him that he would do well in life . that helped a little .',
#   '3549370593': 'of course when [male] the squirrel gave him life advice his whole demeanor turned happily',
#   '3550167922': 'schyler is now ready for life , after the first big chapter ending high school .'},
#  '46492': {'3549332283': '[male] graduated today .',
#   '3550160812': 'the ceremony was long and pompous but worth it .',
#   '3550171580': "his parents were so happy , even though his dad still could n't seem to smile for the camera .",
#   '3549368069': "but his mom 's and aunts ' smiles made up for it .",
#   '3549370593': 'he was happy to be done , but he was going to miss being in college .'},
#  '46493': {'3549332283': '[male] on his graduation day .',
#   '3550160812': '[male] as he hugs his fellow classmate on stage ,',
#   '3550171580': '[male] and [male] are so proud of [male]',
#   '3549368069': 'we took a picture with [male] as well !',
#   '3549370593': 'the location mascot had time for the fresh graduates .'},
#  '46494': {'3549332283': 'we were so proud that our son was graduating already .',
#   '3550160812': 'as he receives his diploma , i had to fight back the tears of joy .',
#   '3550171580': 'hi parents could not be more proud of him .',
#   '3549368069': 'three generations of the family on that special day .',
#   '3549370593': "we had to get him with the team 's mascot just one more time ."},
#  '46495': {'3586730133': 'my sister recently graduated college .',
#   '3587544808': 'graduation was held outdoors on the athletic field .',
#   '3587572878': 'my mom and dad was happy to attend .',
#   '3586760665': 'uncle [male] even came from location .',
#   '3587576040': 'the biggest surprise came last when my brother showed up from location .'},
#  '46496': {'3587572878': 'this is [female] with her mom and dad at the end of the proudest day of her life -- college graduation !',
#   '3587539722': "[female] felt like she was in a dream as she and her classmates walked to their seats . she 'd worked so hard to earn her diploma .",
#   '3587547006': 'there were several speakers before [female] received her diploma . her best friend was valedictorian and gave a rousing speech .',
#   '3587557056': "there 's [female] getting her diploma . she could n't stop smiling .",
#   '3586760665': "[female] 's grandfather was so proud he gave her a big hug ! then the family went to [female] 's favorite restaurant to celebrate . it was a night [female] will always remember ."},
#  '46497': {'3587572878': 'the mom and dad are so proud of their daughter .',
#   '3587539722': 'she is going to get her diploma , what an honor !',
#   '3587547006': 'the podium was well decorated . it was a great experience .',
#   '3587557056': 'there was so many graduates getting their diplomas today .',
#   '3586760665': 'a proud parent with his daughter , at the graduation .'},
#  '46498': {'3587572878': 'we are so proud of our daughter graduating today .',
#   '3587539722': 'it seemed she had to walk miles to receive her diploma .',
#   '3587547006': 'the speeches that were given were very heartwarming .',
#   '3587557056': 'the students pass through one by one to receive their diplomas .',
#   '3586760665': "the world 's proudest grandpa on our special day ."},
#  '46499': {'3586730133': 'she walked to her seat , full of anticipation for the graduation ceremony .',
#   '3587544808': 'graduates took their seats and waited for the ceremony to begin .',
#   '3587572878': 'after the ceremony , she posed with her proud grandparents .',
#   '3586760665': 'she also posed with her other grandfather , who had traveled a long way for the occasion .',
#   '3587576040': 'finally , she posed with he boyfriend , who would graduate next year .'},
#  '46500': {'3618032707': 'today , the whole school came together for a school performance .',
#   '3618032207': 'the stage was beautifully decorated for this performance .',
#   '3618853944': 'one of the classes sang a song .',
#   '3618040983': 'other students had artwork displayed .',
#   '3618033595': 'afterwards , the students enjoyed some snacks .'},
#  '46501': {'3618032207': 'today [female] did a play for the school !',
#   '3618033595': 'she did really well ! afterwards she and her friends went and had a blast around town !',
#   '3618854864': 'they were doing silly things all day .',
#   '3618035115': '[female] was reading the reviews . apparently a producer wants her to star in a film !',
#   '3618036061': 'she is the happiest she could be ! [female] was a little jealous though .'},
#  '46502': {'3618032707': 'our parents all gathered for our student play .',
#   '3618032207': 'the stage was all set with the flowers and rainbow .',
#   '3618853944': 'we sang a few songs that we had learned . location the beautiful was my favorite .',
#   '3618040983': 'we showed our parents the cool mural tiles that we had made for our school mural system .',
#   '3618033595': 'the whole event culminated with a party with food and friends . we had a lot of fun .'},
#  '46503': {'3618032707': 'my school play is today ! i am so excited to perform .',
#   '3618032207': 'our stage was amazing ! we all helped to make it beautiful for our show .',
#   '3618853944': 'we got so much applause and it made us feel so proud .',
#   '3618040983': 'we each painted a brick in the schoolyard to show our creativity .',
#   '3618033595': 'the day was great and the food and sweets www spectacular !'},
#  '46504': {'3618032707': 'the students awaited anxiously as the parents and guests arrived for the open house .',
#   '3618032207': 'the stage was decorated for the event with a floral spring theme .',
#   '3618853944': 'all the children did recitations from memory .',
#   '3618040983': "a small art exhibit was displayed outside showcasing the student 's work .",
#   '3618033595': 'best friends forever after the big day !'},
#  '46505': {'3603621130': 'it was a bright and sunny day yesterday . i was so excited because i was graduating .',
#   '3602815329': 'my boyfriend had shown up to support me as well ! .',
#   '3603635448': 'we took a lot of pictures throughout the day .',
#   '3602833195': "we did n't have much to do while waiting for the ceremony to start .",
#   '3602911037': 'there were tons of people in the stadium after it began .'},
#  '46506': {'3602815329': '[male] and [female] had their first date today .',
#   '3603865462': 'first they went to see some fireworks , which were beautiful .',
#   '3604245468': 'afterwards [male] bought [female] a balloon . she loved the happy face one !',
#   '3603621130': 'afterwards the date ended in the most romantic and passionate way ...',
#   '3602859307': 'with a sweet rock concert !'},
#  '46507': {'3603621130': 'going into the commencement hall . there are beautiful flowers marking this special day .',
#   '3602815329': 'graduates take photos with family and friends to celebrate before attending the ceremony .',
#   '3603635448': 'more happy graduates posing with friends .',
#   '3602833195': 'graduates posing on the steps before entering the hall .',
#   '3602911037': 'graduation ceremony is finally underway .'},
#  '46508': {'3603621130': 'it was a nice summer day when josh and [female] graduated .',
#   '3602815329': "[female] 's little brother came to the ceremony and brought some balloons to celebrate .",
#   '3603635448': "josh 's friends also came to graduation .",
#   '3602833195': 'josh and [female] took some candid photos with their friends .',
#   '3602911037': 'the actual ceremony was inspiring and fun !'},
#  '46509': {'3602815329': 'a couple poses for a picture with balloons .',
#   '3603865462': 'behind them is a huge burst of fireworks .',
#   '3604245468': 'a person in the crowd is a holding a smiley face balloon .',
#   '3603621130': 'a bouquet of flowers grows beside the side walk .',
#   '3602859307': 'a huge concert takes place in the background .'},
#  '46510': {'5693928729': "[male] [male] 's father was murdered .",
#   '5694502862': "thousands gathered for the rich man 's funeral .",
#   '5694503202': 'the funeral parlor was packed with mourners .',
#   '5694503702': '[male] makes his decision to become batman .',
#   '5694503874': 'the citizens of location salute their hero .'},
#  '46511': {'5694501782': 'these individuals represent the high honor graduates for the class of two thousand and fifteen .',
#   '5693928729': 'these individuals represent the two thousand and fifteen high school graduates .',
#   '5694502126': 'the high honor graduates have arrived and waiting to be seated .',
#   '5693929211': 'these are the dignitaries that are present at the graduation .',
#   '5694502472': 'the photographer is capturing some real good shots .'},
#  '46512': {'5693928729': 'the students and teacher pose for a graduation picture .',
#   '5694502862': 'the stadium where they graduate is packed to the brim .',
#   '5694503202': 'there must be over two thousand people there .',
#   '5694503702': 'one of the students is wearing a batman shirt for some laughs .',
#   '5694503874': 'the first student to graduate walks on stage .'},
#  '46513': {'5694501782': 'the entire class was happy to graduate .',
#   '5693928729': 'the ones in the red were going to graduate the year after .',
#   '5694502126': 'people could wear whatever shoes they wanted at the ceremony .',
#   '5693929211': 'the faculty looked proud to be affiliated with the school .',
#   '5694502472': '[male] is the school photographer and we bought some of his photos .'},
#  '46514': {'5694501782': 'i am a professional photographer hired to take graduating photos .',
#   '5693928729': 'here is ptc graduating class of two thousand and fourteen',
#   '5694502126': 'some more ptc graduates .',
#   '5693929211': 'the dean and teachers of organization .',
#   '5694502472': 'here is me the photographer .'},
#  '46515': {'5742248788': 'they picked the winners for the scholarships today .',
#   '5741695647': 'many young people were chosen for them .',
#   '5742249490': 'they had a speaker congratulate them .',
#   '5742249548': 'everyone was so proud to receive their scholarship .',
#   '5742249572': 'the families were really happy and it was great seeing them together .'},
#  '46516': {'5741695647': 'i had a great time at the meeting .',
#   '5741695851': 'i got to meet a lot of new and interesting people .',
#   '5742249098': 'they were very funny .',
#   '5742249364': 'afterward we got something to eat .',
#   '5741696215': 'there were some speakers there as well .'},
#  '46517': {'5742248788': 'people prefer to be around nice people .',
#   '5741695647': '[female] is one of the nicest people at a university .',
#   '5742249490': 'a counselor spoke about how healthy graduating is .',
#   '5742249548': 'the women took a picture with a few grateful boys .',
#   '5742249572': 'everyone was proud of each other that day .'},
#  '46518': {'5742248788': 'the students arrived to the ceremony at organization .',
#   '5741695647': 'the students listened while the speaker gave a speech .',
#   '5742249490': 'the speaker presented before the group of students .',
#   '5742249548': 'some of the students received gifts at the conference .',
#   '5742249572': 'at the end , they all gathered for a group photo .'},
#  '46519': {'5742248788': 'today was the awards ceremony over at organization ! i was glad to be there .',
#   '5741695647': 'so was my lovely girlfriend .',
#   '5742249490': "the staff seemed to be too , though they 're getting paid so who knows .",
#   '5742249548': 'congratulations to all the winners !',
#   '5742249572': "here 's to next time guys . great work ."},
#  '46520': {'5808595429': 'they opened the ceremony with a very strong thesis presentation .',
#   '5809163792': 'it was presented on natural gas and its contribution to the power community .',
#   '5809156380': 'following the ceremony , they gathered outside .',
#   '5809161236': 'along with their entire family and took a photo ...',
#   '5808611567': 'then they went inside and watched the rest of the ceremony .'},
#  '46521': {'5809163792': 'everyone was very excited at the graduation ceremony .',
#   '5809165040': 'there were a lot of military members present .',
#   '5808604465': 'there was a thesis statement as well .',
#   '5808611567': 'all of the staff were very proud .',
#   '5808615527': 'i had a great time there .'},
#  '46522': {'5809163792': 'the graduates were shown a movie about global warming .',
#   '5809165040': 'they all sat in confusion and boredom .',
#   '5808604465': 'a speaker told them to imagine that they just won the lottery .',
#   '5808611567': 'the teachers looked confused in regard to that statement .',
#   '5808615527': 'professor smith was the most confused out of everyone .'},
#  '46523': {'5808595429': 'the final project before graduating was the thesis presentation to the panel .',
#   '5809163792': 'each student gave their presentation on stage .',
#   '5809156380': 'when it came time for the graduation ceremony , they stood next to their classmates .',
#   '5809161236': 'then , the graduates posed with their colleagues and family members .',
#   '5808611567': 'finally , they walked across the stage and collected their accolades .'},
#  '46524': {'5809163792': 'the class was graduating . before the ceremony , the students presented a power point .',
#   '5809165040': 'they presented it to the military audience .',
#   '5808604465': 'they explained their ongoing project and thesis statement .',
#   '5808611567': 'the professors lined up to congratulate the graduates .',
#   '5808615527': 'after all of their hard work , the students walked down the aisle and received their diplomas .'},
#  '46525': {'5822651394': '[female] was excited to graduate .',
#   '5822651354': 'she smiled with her mom .',
#   '5822087063': 'she smiled with her sister .',
#   '5822086997': 'she kissed her sister simultaneously with her mom .',
#   '5822651648': 'then she went crazy and whacked the camera man !'},
#  '46526': {'5822651132': 'this young lady is graduating today .',
#   '5822350514': 'this young lady and her proud mother pose for a picture before the graduation .',
#   '5822651186': 'the young lady sits in the crowd and listens to the ceremony and waits to receive her diploma .',
#   '5822651718': 'the young lady gets her diploma and walks across the stage .',
#   '5822651354': 'the young lady takes a picture with her diploma and her proud mother .'},
#  '46527': {'5822651132': 'my graduation ceremony was a success .',
#   '5822350514': 'mother was more proud of me than her old proudest moment , when i was born .',
#   '5822651186': 'the ceremony lasted about thirty minutes .',
#   '5822651718': 'they yelled out my name and off i went with my diploma .',
#   '5822651354': 'mother says she can not wait for me to make money so she can afford to buy a beach condo .'},
#  '46528': {'5822651132': 'she was ready to go to her graduation .',
#   '5822350514': 'the family took a few final photos before leaving .',
#   '5822651186': 'she sat in the crowd waiting patiently for her diploma .',
#   '5822651718': 'it was her turn to walk across the stage to receive her diploma .',
#   '5822651354': 'they were so happy she graduated .'},
#  '46529': {'5822651394': 'after many years of working as a waitress during the day and going to school at night , today was her time to shine .',
#   '5822651354': 'the new graduate showed off her diploma and posed with her roommate .',
#   '5822087063': 'next , she posed with her younger sister .',
#   '5822086997': "the little sister was a bit startled when her older sister and sister 's roommate smothered her with kisses .",
#   '5822651648': "finally , the new graduate made her way off the school 's green field for the last time ."},
#  ...}

# %%
story_id = "45530"
story_df = sis_test_annotations_df[sis_test_annotations_df["story_id"] == story_id]
story_df
# Out:
#                                        original_text album_id photo_flickr_id  \
# 0     The local parish holds a craft show each year.    44277         1741642
# 1  Lots of folks come out and set up tables to se...    44277         1741640
# 2  Some of these crafts are very unique and take ...    44277         1741632
# 3  Folks of all ages come out to peruse the craft...    44277         1741622
# 4  Some of the crafters even dress up in unique c...    44277         1741587
#
#                  setting        worker_id story_id               tier  \
# 0  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
# 1  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
# 2  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
# 3  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
# 4  first-2-pick-and-tell  FJROI8NWDRIPAM1    45530  story-in-sequence
#
#    worker_arranged_photo_order  \
# 0                            0
# 1                            1
# 2                            2
# 3                            3
# 4                            4
#
#                                                 text storylet_id
# 0    the local parish holds a craft show each year .      227650
# 1  lots of folks come out and set up tables to se...      227651
# 2  some of these crafts are very unique and take ...      227652
# 3  folks of all ages come out to peruse the craft...      227653
# 4  some of the crafters even dress up in unique c...      227654

# %%
answer_dict = {}
modified_dict = {}
drop_pos = 2  # 除外したいworker_arranged_photo_order

for story_id, group in sis_test_annotations_df.groupby("story_id"):
    group = group.sort_values("worker_arranged_photo_order")
    # 答え（order==drop_posのもの）
    answer_row = group[group["worker_arranged_photo_order"] == drop_pos]
    if not answer_row.empty:
        ans_photo_id = answer_row.iloc[0]["photo_flickr_id"]
        ans_text = answer_row.iloc[0]["text"]
        answer_dict[story_id] = {ans_photo_id: ans_text}
    # modified_dictにはdrop_posのものを入れない
    photo_text_dict = {
        row["photo_flickr_id"]: row["text"]
        for _, row in group.iterrows()
        if row["worker_arranged_photo_order"] != drop_pos
    }
    modified_dict[story_id] = photo_text_dict

# %%
# 答えの例
print("answer_dictの例:", list(answer_dict.items())[0])
# 空にしたデータの例
print("modified_dictの例:", list(modified_dict.items())[0])
# Out:
# answer_dictの例: ('45530', {'1741632': 'some of these crafts are very unique and take a lot of talent to make .'})
# modified_dictの例: ('45530', {'1741642': 'the local parish holds a craft show each year .', '1741640': 'lots of folks come out and set up tables to sell their crafts .', '1741622': 'folks of all ages come out to peruse the crafts for sale .', '1741587': 'some of the crafters even dress up in unique costumes as part of their selling act .'})

# %%
answers = list(answer_dict.items())
questions = list(modified_dict.items())

# %%
print(answers[:2])
print(questions[:2])
# Out:
# [('45530', {'1741632': 'some of these crafts are very unique and take a lot of talent to make .'}), ('45531', {'1741639': "i stopped at chatted at my friend [female] 's booth for a bit ."})]
# [('45530', {'1741642': 'the local parish holds a craft show each year .', '1741640': 'lots of folks come out and set up tables to sell their crafts .', '1741622': 'folks of all ages come out to peruse the crafts for sale .', '1741587': 'some of the crafters even dress up in unique costumes as part of their selling act .'}), ('45531', {'1741625': 'i was so excited to be heading to the crafts fair .', '1741640': 'when i arrived i saw a great booth with a variety of great crafts .', '1741633': 'there were even booths set up for all of the kids .', '1741630': "i found some awesome crafts at the fair , i 'm really happy that i went ."})]

# %%
print(len(answers))
print(len(questions))
# Out:
# 5055
# 5055

# %%
options_dict = {}
answer_index_dict = {}

n_options = 4  # 選択肢数
seed = 42
random.seed(seed)  # 一度だけseedを設定

# 全storyのphoto_flickr_id-textペアを集める（重複除外）
all_photo_text = set()
for d in modified_dict.values():
    all_photo_text.update(d.items())
all_photo_text = list(all_photo_text)

for story_id in answer_dict.keys():
    correct_pair = list(answer_dict[story_id].items())[0]  # (photo_flickr_id, text)
    # 不正解候補（正解と同じphoto_flickr_id/textは除外）
    negatives = [
        item
        for item in all_photo_text
        if item[0] != correct_pair[0] and item[1] != correct_pair[1]
    ]
    sampled_neg = random.sample(negatives, min(n_options - 1, len(negatives)))
    # optionsリスト作成
    options = [correct_pair] + sampled_neg
    random.shuffle(options)
    # photo_flickr_id: text の辞書に変換
    options_dict[story_id] = {k: v for k, v in options}
    # 正解の位置をstory_id: indexで記録
    correct_index = [i for i, (k, _) in enumerate(options) if k == correct_pair[0]][0]
    answer_index_dict[story_id] = correct_index

# 例の出力
sample_story_id = list(options_dict.keys())[0]
print("options例:", options_dict[sample_story_id])
print("正解インデックス例:", answer_index_dict[sample_story_id])
# Out:
# options例: {'45185352': 'champagne , a limo . next stop , honeymoon .', '1183920': 'here i am getting ready .', '1741632': 'some of these crafts are very unique and take a lot of talent to make .', '1584818205': 'this is a prime example of how hard working ants really are .'}
# 正解インデックス例: 2

# %%
options = list(options_dict.items())
answer_indices = list(answer_index_dict.items())

# %%
print(len(options))
print(len(answer_indices))
# Out:
# 5055
# 5055

# %%
print(options[:2])
print(answer_indices[:10])
# Out:
# [('45530', {'45185352': 'champagne , a limo . next stop , honeymoon .', '1183920': 'here i am getting ready .', '1741632': 'some of these crafts are very unique and take a lot of talent to make .', '1584818205': 'this is a prime example of how hard working ants really are .'}), ('45531', {'176018513': 'we got to sit really close to the players .', '4495759906': 'the makeup artist did their job .', '1741639': "i stopped at chatted at my friend [female] 's booth for a bit .", '5110133803': 'plain [female] , the barkeep , enjoyed the show , and would keep smiling , until they later burnt her at the stake , mistaking her for a witch .'})]
# [('45530', 2), ('45531', 2), ('45532', 3), ('45533', 0), ('45534', 1), ('45535', 3), ('45536', 2), ('45537', 3), ('45538', 3), ('45539', 3)]

# %%
final_json = {}

for story_id in answer_dict.keys():
    final_json[story_id] = {
        "question": modified_dict[story_id],  # ポジション2が欠けた画像テキスト列の辞書
        "answer": answer_dict[story_id],  # 正解の画像IDとテキストの辞書
        "option": options_dict[story_id],  # 選択肢となる画像テキスト対の辞書
        "answer_idx": answer_index_dict[story_id],  # 正解の選択肢インデックス
        "drop_pos": drop_pos,  # 除外したポジション
    }

# 例の出力（最初の1件だけ表示）
sample_story_id = list(final_json.keys())[0]

print(
    json.dumps(
        {sample_story_id: final_json[sample_story_id]}, ensure_ascii=False, indent=2
    )
)
# Out:
# {
#   "45530": {
#     "question": {
#       "1741642": "the local parish holds a craft show each year .",
#       "1741640": "lots of folks come out and set up tables to sell their crafts .",
#       "1741622": "folks of all ages come out to peruse the crafts for sale .",
#       "1741587": "some of the crafters even dress up in unique costumes as part of their selling act ."
#     },
#     "answer": {
#       "1741632": "some of these crafts are very unique and take a lot of talent to make ."
#     },
#     "option": {
#       "45185352": "champagne , a limo . next stop , honeymoon .",
#       "1183920": "here i am getting ready .",
#       "1741632": "some of these crafts are very unique and take a lot of talent to make .",
#       "1584818205": "this is a prime example of how hard working ants really are ."
#     },
#     "answer_idx": 2,
#     "drop_pos": 2
#   }
# }

# %%
# JSONL で保存
output_path = "seq2opt.jsonl"
with open(output_path, "w", encoding="utf-8") as f:
    for story_id, rec in final_json.items():
        record = {"story_id": story_id, **rec}
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

print(f"保存しました: {output_path}")
